# %% [markdown]
# # Analysis & Insights Report

# %% [markdown]
# ### Introduction

# %% [markdown]
# WeRateDogs is a Twitter account that rates people's dogs with a humorous comment
# about the dog. <br>
# These ratings almost always have a denominator of 10. <br>
# The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc.<br>
# " WeRateDogs has over 7.89M followers (on March 2019) and has received
# international media coverage

# %% [markdown]
# - So Which dog type (breed) is the most common dog in the tweet dataset?
# - What dog type has the highest average rating?
# - How the Twitter account evolved over time?
# - These questions and more are answered in the following insights

# %% [markdown]
# There are some insights I have found:
#
#    1. The most dog type predicted is Golden retriever.
#
#    2. The most names used to identify dogs are Lucy and Charlie.
#
#    3. The most favorite dogs type is the Lakeland Terrier

# %% [markdown]
# Here are some visuals:

# %% [markdown]
# ### Most common Dog Types
#
# WeRateDogs has over 6000+ tweets. I was able to analyzed around 2000+ tweets. <br>
# Golden Retriever with 150, Labrador Retriever with 100, Pembroke with 89,<br>
# and Chihuahua with 87 are the most popular dog types!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Most popular names
#
# As the graph below shows, we can see that the fives most popular names <br>
# of dogs in our dataset were "Charlie", "Lucy", "Oliver",<br>
# "Cooper" and "Tucker"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Most Favorite dog
#
# From the graph below we see that dogs that have most number of favorite tweets are:
# - Lakeland Terrier
# - Labrador Retriever
# - English Springer
# - Chihuahua
# - French Bulldog

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Most predicted dog types (part 2)
#
# We have deepen our search into the dog types predicted to see how <br>
# the classification algorithm perform for second and third predictions.<br>
# And as the most first (p1) predictions we see that <br>
# Labrador Retriever and Golden Retriever are still on the top eventhough <br>
# Chihuahua (P2) and Cardigan (P3) took the place of Pembroke in the top trio. <br>
# From this we can suppose that the dataset used to train the classification model (algorithm) <br>
# was majoritary build with these dogs(Labrador Retriever and Golden Retriever) pictures. <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Account Popularity over Time
#
# The page gained popularity over time as it is clear in the below graph. <br>
# We see an upward trend in the number of favorites per year. <br>
# We can suppose that tweets were getting more and more favorites as WeRateDog account was becoming more and more
# popular

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Relationship between Favorite count and Retweet count
#
# From the graph below we can see that there is a positive correlation between Favorite count and Retweet count.<br>
# So we can suppose that the popularity of the WeRateDogs is related to their favorite dogs.

# %% [markdown]
# ![image.png](attachment:image.png)
